# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %% [markdown]
# # Real World Python Data Analysis
#
# Hello, I'm **Ademola Abraham**, a **Health Information Data Analyst**, and I will be working with a real world diabetes dataset called **Healthcare Diabetes dataset**, which is in the Csv format and was gotten from kaggle dataset [here](https://).
#
# I will be using Python data analysis to work on the data by performing some exploratory analysis and visualization of the dataset, then finding solutions and answers to problems and questions that comes from the dataset, finally giving some insights concerning the dataset.
#
#
#
#
# # Data Preparation and Cleaning

# %%
raw_data = pd.read_csv(r'Healthcare-Diabetes.csv')
raw_data
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1            6      148             72             35        0  33.6
# 1        2            1       85             66             29        0  26.6
# 2        3            8      183             64              0        0  23.3
# 3        4            1       89             66             23       94  28.1
# 4        5            0      137             40             35      168  43.1
# ...    ...          ...      ...            ...            ...      ...   ...
# 2763  2764            2       75             64             24       55  29.7
# 2764  2765            8      179             72             42      130  32.7
# 2765  2766            6       85             78              0        0  31.2
# 2766  2767            0      129            110             46      130  67.1
# 2767  2768            2       81             72             15       76  30.1
#
# ...

# %%
raw_data.duplicated().sum()
# Out:
# 0

# %%
raw_data.isnull().sum()
# Out:
# Id                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        2768 non-null   int64
#  1   Pregnancies               2768 non-null   int64
#  2   Glucose                   2768 non-null   int64
#  3   BloodPressure             2768 non-null   int64
#  4   SkinThickness             2768 non-null   int64
#  5   Insulin                   2768 non-null   int64
#  6   BMI                       2768 non-null   float64
#  7   DiabetesPedigreeFunction  2768 non-null   float64
#  8   Age                       2768 non-null   int64
#  9   Outcome                   2768 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 216.4 KB

# %%
raw_data['Outcome'] = raw_data['Outcome'].astype('bool')

# %%
raw_data.describe()
# Out:
#                 Id  Pregnancies      Glucose  BloodPressure  SkinThickness  \
# count  2768.000000  2768.000000  2768.000000    2768.000000    2768.000000
# mean   1384.500000     3.742775   121.102601      69.134393      20.824422
# std     799.197097     3.323801    32.036508      19.231438      16.059596
# min       1.000000     0.000000     0.000000       0.000000       0.000000
# 25%     692.750000     1.000000    99.000000      62.000000       0.000000
# 50%    1384.500000     3.000000   117.000000      72.000000      23.000000
# 75%    2076.250000     6.000000   141.000000      80.000000      32.000000
# max    2768.000000    17.000000   199.000000     122.000000     110.000000
#
#            Insulin          BMI  DiabetesPedigreeFunction          Age
# count  2768.000000  2768.000000               2768.000000  2768.000000
# mean     80.127890    32.137392                  0.471193    33.132225
# std     112.301933     8.076127                  0.325669    11.777230
# ...

# %% [markdown]
# # Exploratory Analysis and Visualization

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(data=raw_data, x='Age', y='SkinThickness', hue='Outcome')
plt.title('Relationship of Age with skin thickness and outcome');

# %%
plt.figure(figsize=(7,7))
sns.countplot(data=raw_data, x='Outcome')
plt.title('Number of people with and without Diabetes')
plt.ylabel('Number of people')
plt.grid();

# %%
plt.figure(figsize=(14,7))
sns.histplot(data=raw_data, x='DiabetesPedigreeFunction', hue='Outcome')
plt.title('Relationship of Diabetes pedigree function count with outcome')
plt.ylabel('Number of people')
plt.grid();

# %%
plt.figure(figsize=(14,7))
sns.histplot(data=raw_data, x='Age', hue='Outcome')
plt.title('Relationship betwen Age and Outcome');

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(data=raw_data, x='Age', y='DiabetesPedigreeFunction', hue='Outcome')
plt.title('Relationship of age with diabetespedigreefunction and outcome');

# %%
plt.figure(figsize=(12,5))
plt.pie(x=raw_data.Outcome.value_counts(), labels=raw_data.Outcome.unique(), autopct='%.1f%%')
plt.title('Percent of those with Diabetes and those without');

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(data=raw_data, x='Age', y='DiabetesPedigreeFunction', hue='Outcome')
plt.title('Relationship of Age with diabetes pedigree function and outcome');

# %%
plt.figure(figsize=(14,7))
sns.countplot(data=raw_data, y=raw_data.Pregnancies, hue='Outcome')
plt.title('');

# %%
sns.pairplot(raw_data[['Glucose', 'BloodPressure', 'Insulin', 'BMI', 'DiabetesPedigreeFunction']])
plt.tight_layout();

# %% [markdown]
# # Questions and Answers
#
# ## 1. How many people had a Diabetes Pedigree Function greater than 2.42?

# %%
a = raw_data[(raw_data['DiabetesPedigreeFunction'] >= 2.42)]
a
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 445    446            0      180             78             63       14  59.4
# 1213  1214            0      180             78             63       14  59.4
# 1683  1684            0      180             78             63       14  59.4
# 2272  2273            0      180             78             63       14  59.4
#
#       DiabetesPedigreeFunction  Age  Outcome
# 445                       2.42   25     True
# 1213                      2.42   25     True
# 1683                      2.42   25     True
# 2272                      2.42   25     True

# %%
a.shape
# Out:
# (4, 10)

# %%
print('''
How many people had a Diabetes Pedigree Function greater than 2.42?
Answer: {}'''.format(a.shape[0]))
# Out:
# How many people had a Diabetes Pedigree Function greater than 2.42?
# Answer: 4

# %% [markdown]
# ## 2. How many people had a normal BMI and had Diabetes?

# %%
# normal BMI = (18.5 to 24.9)
b = raw_data[(raw_data['BMI'] >= 18.5) & (raw_data['BMI'] <= 24.9) & (raw_data['Outcome'] == 1)]
b
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2        3            8      183             64              0        0  23.3
# 93      94            4      134             72              0        0  23.8
# 197    198            3      107             62             13       48  22.9
# 319    320            6      194             78              0        0  23.5
# 646    647            1      167             74             17      144  23.4
# 676    677            9      156             86              0        0  24.8
# 749    750            6      162             62              0        0  24.3
# 861    862            4      134             72              0        0  23.8
# 965    966            3      107             62             13       48  22.9
# 1087  1088            6      194             78              0        0  23.5
# 1414  1415            1      167             74             17      144  23.4
# ...

# %%
b.shape
# Out:
# (25, 10)

# %%
print('''
How many people had a normal BMI and had Diabetes?
Answer: {}'''.format(b.shape[0]))
# Out:
# How many people had a normal BMI and had Diabetes?
# Answer: 25

# %% [markdown]
# ## 3. How many people had a normal Glucose level and has diabetes?

# %%
c = raw_data[(raw_data['Glucose'] >=70) & (raw_data['Glucose'] <=100) & (raw_data['Outcome'] == 1)]
c
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 6        7            3       78             50             32       88  31.0
# 15      16            7      100              0              0        0  30.0
# 38      39            2       90             68             42        0  38.2
# 70      71            2      100             66             20       90  32.9
# 109    110            0       95             85             25       36  37.4
# ...    ...          ...      ...            ...            ...      ...   ...
# 2575  2576            5       97             76             27        0  35.6
# 2627  2628            2       90             68             42        0  38.2
# 2659  2660            2      100             66             20       90  32.9
# 2698  2699            0       95             85             25       36  37.4
# 2714  2715            1       88             30             42       99  55.0
#
# ...

# %%
c.shape
# Out:
# (63, 10)

# %%
print('''
How many people had a normal Glucose level and has diabetes?
Answer: {}'''.format(c.shape[0]))
# Out:
# How many people had a normal Glucose level and has diabetes?
# Answer: 63

# %% [markdown]
# ## 4. How many people had a normal Glucose level and didn't have diabetes?

# %%
d = raw_data[(raw_data['Glucose'] >=70) & (raw_data['Glucose'] <=100) & (raw_data['Outcome'] == 0)]
d
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1        2            1       85             66             29        0  26.6
# 3        4            1       89             66             23       94  28.1
# 21      22            8       99             84              0        0  35.4
# 27      28            1       97             66             15      140  23.2
# 32      33            3       88             58             11       54  24.8
# ...    ...          ...      ...            ...            ...      ...   ...
# 2761  2762            2       87              0             23        0  28.9
# 2762  2763            1       79             60             42       48  43.5
# 2763  2764            2       75             64             24       55  29.7
# 2765  2766            6       85             78              0        0  31.2
# 2767  2768            2       81             72             15       76  30.1
#
# ...

# %%
d.shape
# Out:
# (659, 10)

# %%
print('''
How many people had a normal Glucose level and didn't have diabetes?
Answer: {} people'''.format(d.shape[0]))
# Out:
# How many people had a normal Glucose level and didn't have diabetes?
# Answer: 659 people
